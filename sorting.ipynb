# %%
from qiskit import QuantumCircuit
from qiskit import QuantumRegister
from numpy import pi
from qiskit import ClassicalRegister

# %%
qreg_a = QuantumRegister(2, 'a')
qreg_b = QuantumRegister(2, 'b')
qreg_m = QuantumRegister(2, 'm')
qreg_n = QuantumRegister(2, 'n')
qreg_c = QuantumRegister(1, 'c')
qreg_o = QuantumRegister(1, 'o')
qreg_q = QuantumRegister(1, 'q')
qreg_d = QuantumRegister(1, 'd')
qreg_g = QuantumRegister(1, 'g')
qreg_j = QuantumRegister(1, 'j')
qreg_k = QuantumRegister(1, 'k')
qreg_l = QuantumRegister(1, 'l')
qreg_r = QuantumRegister(1, 'r')
qreg_uu = QuantumRegister(1, 'uu')
qreg_zz = QuantumRegister(1, 'zz')
qreg_control = QuantumRegister(6, 'control')
creg_sorted = ClassicalRegister(8, 'sorted')
qc= QuantumCircuit(qreg_a, qreg_b, qreg_m, qreg_n, qreg_c, qreg_o, qreg_q, qreg_d, qreg_g, qreg_j, qreg_k, qreg_l, qreg_r, qreg_uu, qreg_zz, qreg_control, creg_sorted)

qc.x(1)
qc.x(0)
qc.x(1)
qc.x(0)
qc.x(0)
qc.x(0)
qc.h(0)
qc.cswap(0,0,0)
qc.cswap(0,1,1)
qc.h(1)
qc.cswap(1,0,0)
qc.cswap(1,1,1)
qc.h(2)
qc.cswap(2,0,0)
qc.cswap(2,1,1)
qc.h(3)
qc.cswap(3,0,0)
qc.cswap(3,1,1)
qc.h(4)
qc.cswap(4,0,0)
qc.x(0)
qc.cswap(4, 1, 1)
qc.x(1)
qc.ccx(1, 1, 0)
qc.ccx(0, 1, 0)
qc.swap(1, 0)
qc.x(1)
qc.swap(1, 0)
qc.ccx(0, 0, 0)
qc.swap(0, 0)
qc.x(0)
qc.ccx(1, 0, 0)
qc.x(0)
qc.swap(0, 0)
qc.reset(0)
qc.x(0)
qc.x(1)
qc.swap(1, 0)
qc.reset(0)
qc.ccx(0, 0, 0)
qc.swap(0, 0)
qc.x(0)
qc.reset(0)
qc.x(0)
qc.x(1)
qc.ccx(1, 0, 0)
qc.x(0)
qc.swap(0, 0)
qc.reset(0)
qc.x(0)
qc.x(1)
qc.swap(1, 0)
qc.reset(0)
qc.x(1)
qc.h(5)
qc.cswap(5, 0, 0)
qc.x(0)
qc.x(0)
qc.cswap(5, 1, 1)
qc.x(1)
qc.ccx(1, 1, 0)
qc.ccx(0, 1, 0)
qc.swap(1, 0)
qc.x(1)
qc.swap(1, 0)
qc.ccx(0, 0, 0)
qc.swap(0, 0)
qc.x(0)
qc.ccx(1, 0, 0)
qc.x(0)
qc.swap(0, 0)
qc.reset(0)
qc.x(0)
qc.x(1)
qc.swap(1, 0)
qc.reset(0)
qc.ccx(0, 0, 0)
qc.swap(0, 0)
qc.reset(0)
qc.x(0)
qc.x(0)
qc.x(1)
qc.ccx(1, 0, 0)
qc.x(0)
qc.swap(0, 0)
qc.ccx(0, 0, 0)
qc.reset(0)
qc.x(0)
qc.swap(0, 0)
qc.reset(0)
qc.x(1)
qc.swap(1, 0)
qc.reset(0)
qc.x(1)
qc.x(1)
qc.ccx(1, 1, 0)
qc.ccx(0, 1, 0)
qc.swap(1, 0)
qc.x(1)
qc.swap(1, 0)
qc.ccx(0, 0, 0)
qc.swap(0, 0)
qc.x(0)
qc.ccx(1, 0, 0)
qc.x(0)
qc.swap(0, 0)
qc.reset(0)
qc.x(1)
qc.swap(1, 0)
qc.reset(0)
qc.ccx(0, 0, 0)
qc.swap(0, 0)
qc.reset(0)
qc.x(0)
qc.x(0)
qc.x(1)
qc.ccx(1, 0, 0)
qc.x(0)
qc.swap(0, 0)
qc.reset(0)
qc.ccx(0, 0, 0)
qc.swap(0, 0)
qc.reset(0)
qc.ccx(0, 0, 0)
qc.swap(0, 0)
qc.x(1)
qc.swap(1, 0)
qc.reset(0)
qc.ccx(1, 0, 0)
qc.swap(1, 0)
qc.ccx(0, 0, 0)
qc.swap(0, 0)
qc.ccx(1, 0, 0)
qc.swap(1, 0)
qc.ccx(0, 0, 0)
qc.swap(0, 0)
qc.ccx(1, 0, 0)
qc.swap(1, 0)
qc.ccx(0, 0,0)
qc.swap(0,0)
qc.x(1)
qc.ccx(1, 0,0)
qc.swap(1,0)
qc.measure(0,0)
qc.measure(1,1)
qc.measure(0,2)
qc.measure(1,3)
qc.measure(0,4)
qc.measure(1,5)
qc.measure(0,6)
qc.measure(1,7)
# Out:
# ---------------------------------------------------------------------------
# CircuitError                              Traceback (most recent call last)
# Cell In[6], line 27
#      25 qc.x(0)
#      26 qc.h(0)
# ---> 27 qc.cswap(0,0,0)
#      28 qc.cswap(0,1,1)
#      29 qc.h(1)
#
# File c:\Users\subha\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit\circuit\quantumcircuit.py:3639, in QuantumCircuit.cswap(self, control_qubit, target_qubit1, target_qubit2, label, ctrl_state)
#    3621 """Apply :class:`~qiskit.circuit.library.CSwapGate`.
#    3622
#    3623 For the full matrix form of this gate, see the underlying gate documentation.
#    (...)
#    3635     A handle to the instructions created.
#    3636 """
#    3637 from .library.standard_gates.swap import CSwapGate
# -> 3639 return self.append(
#    3640     CSwapGate(label=label, ctrl_state=ctrl_state),
#    3641     [control_qubit, target_qubit1, target_qubit2],
#    3642     [],
#    3643 )
#
# File c:\Users\subha\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit\circuit\quantumcircuit.py:1314, in QuantumCircuit.append(self, instruction, qargs, cargs)
#    1312 if isinstance(operation, Instruction):
#    1313     for qarg, carg in operation.broadcast_arguments(expanded_qargs, expanded_cargs):
# -> 1314         self._check_dups(qarg)
#    1315         instruction = CircuitInstruction(operation, qarg, carg)
#    1316         appender(instruction)
#
# File c:\Users\subha\AppData\Local\Programs\Python\Python310\lib\site-packages\qiskit\circuit\quantumcircuit.py:1545, in QuantumCircuit._check_dups(self, qubits)
#    1543 squbits = set(qubits)
#    1544 if len(squbits) != len(qubits):
# -> 1545     raise CircuitError("duplicate qubit arguments")
#
# CircuitError: 'duplicate qubit arguments'
